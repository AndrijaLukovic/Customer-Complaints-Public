# %%
import pandas as pd
import numpy as np
from os import path
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import nltk
from nltk.corpus import stopwords 

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataset = pd.read_csv("/home/andrija/Desktop/customer_complaints/complaints-2017-12-08_11_01.csv")

# %%
dataset.head()
# Out:
#   Date received                  Product                         Sub-product  \
# 0      06/19/12                 Mortgage  Home equity loan or line of credit
# 1      04/06/12                 Mortgage                      Other mortgage
# 2      01/25/17                 Mortgage                      Other mortgage
# 3      06/03/15  Bank account or service                    Checking account
# 4      02/24/14  Bank account or service                    Checking account
#
#                                       Issue Sub-issue  \
# 0  Loan modification,collection,foreclosure       NaN
# 1  Loan modification,collection,foreclosure       NaN
# 2  Loan modification,collection,foreclosure       NaN
# 3   Account opening, closing, or management       NaN
# 4                  Deposits and withdrawals       NaN
#
#   Consumer complaint narrative  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
#
#                              Company public response                Company  \
# 0                                                NaN  WELLS FARGO & COMPANY
# 1                                                NaN  WELLS FARGO & COMPANY
# 2  Company has responded to the consumer and the ...  WELLS FARGO & COMPANY
# 3   Company chooses not to provide a public response  WELLS FARGO & COMPANY
# 4                                                NaN  WELLS FARGO & COMPANY
#
#   State ZIP code           Tags Consumer consent provided? Submitted via  \
# 0    TN    37777  Servicemember                        NaN           Web
# 1    NJ    07040            NaN                        NaN           Web
# 2    NC    28801            NaN                      Other           Web
# 3    TX    75219            NaN                        NaN      Referral
# 4    AZ    85266            NaN                        NaN           Web
#
#   Date sent to company     Company response to consumer Timely response?  \
# 0             06/22/12  Closed with non-monetary relief              Yes
# 1             04/06/12            Closed without relief              Yes
# 2             01/27/17          Closed with explanation              Yes
# 3             06/04/15          Closed with explanation              Yes
# 4             02/24/14          Closed with explanation              Yes
#
#   Consumer disputed?  Complaint ID
# 0                 No        104331
# 1                 No         44595
# 2                 No       2310077
# 3                Yes       1403461
# 4                 No        728114

# %% [markdown]
# ## Word Clouds

# %%
# ?WordCloud

# %%
narrative = dataset['Consumer complaint narrative'].copy(deep=True)

issue = dataset['Issue'].copy(deep=True)

# %%
text = narrative[15]

text1 = issue[5]

# %%
stopwords = set(STOPWORDS)
stopwords.update(["XXXX", 'XX', 'Wells', 'Fargo'])

wordcloud = WordCloud(max_font_size=100, max_words=200, width=1000, height=800,
                      stopwords=stopwords, background_color="white").generate(text)

wordcloud1 = WordCloud(max_font_size=100, max_words=200, width=1000, height=800,
                      stopwords=stopwords, background_color="white").generate(text1)

# %%
plt.imshow(wordcloud, interpolation='bilinear')

plt.axis("off")
plt.show()

# %%
plt.imshow(wordcloud1, interpolation='bilinear')

plt.axis("off")
plt.show()

# %% [markdown]
# ## Tokenization

# %%
stop_words = set(stopwords.words('english'))
stop_words.add('XXXX')

# %%
word_tokens = nltk.word_tokenize(text)

# %%
filtered_sentence = []

for w in word_tokens:
    if w not in stop_words:
        filtered_sentence.append(w)

# %%
print(filtered_sentence)
# Out:
# ['In', 'previous', 'correspondence', 'replies', 'Wells', 'Fargo', 'Home', 'Mortgage', ',', 'generated', 'robo', 'letter', 'states', ',', '``', 'Wells', 'Fargo', 'unable', 'establish', 'contact', '``', '.', 'With', 'correspondence', 'sent', 'owing', 'home', '10', 'years', 'changing', 'phone', 'number', ',', 'email', ',', 'etc', '.', 'The', 'information', 'remained', ',', 'additionally', 'I', 'attempted', 'establish', 'contact', 'new', 'point', 'contact', '(', ')', '.', 'After', 'visiting', 'Wells', 'Fargo', 'branch', ',', 'located', 'chatting', 'representative', '.', 'I', 'attempted', 'two', 'phone', 'calls', 'direct', '(', ')', ',', 'went', 'directly', 'voicemail', ',', 'without', 'return', 'phone', 'call', 'email', ',', 'etc', '.', 'I', 'come', 'conclusion', 'Wells', 'Fargo', 'Home', 'Mortgage', 'want', 'solve', 'issue', 'I', 'may', 'resolve', 'confusion', 'accounts', '.', 'What', 'today', ',', 'listen', 'concerns', 'intently', 'assured', 'would', 'everything', 'power', 'control', 'make', 'certain', 'I', 'pleasurable', 'experience', 'moving', 'forward', '.', 'Since', 'first', 'contacting', 'Wells', 'Fargo', 'Home', 'Mortgage', 'numerous', 'points', 'contacts', 'hope', 'obtain', 'sort', 'resolution', 'payments', 'applied', '.', 'Not', 'Wells', 'Fargo', 'Home', 'Mortgage', 'request', 'receipts', ',', 'bills', ',', 'proof', ',', 'yet', 'continue', 'send', 'information', 'collection', 'foreclosure', 'bureaus', '.', 'It', 'disturbing', 'conglomerate', 'magnitude', 'operates', 'low', 'level', '.', 'Attached', 'payment', 'history', 'I', 'deposited', 'daily', 'basis', '.', 'Store', '#', '{', '$', '760.00', '}', '.', 'Store', '#', '{', '$', '760.00', '}', '.', 'Store', '#', '{', '$', '760.00', '}', '.', 'Store', '#', '{', '$', '760.00', '}', '.', '#', '{', '$', '810.00', '}', '.', 'Store', '#', '{', '$', '810.00', '}', '.', 'Store', '#', '{', '$', '810.00', '}', '.', '#', '{', '$', '800.00', '}', '.', 'Store', '#', '{', '$', '840.00', '}', '.', 'Store', '#', '{', '$', '770.00', '}', '.', '#', '{', '$', '50.00', '}', '.', 'Store', '#', '{', '$', '1300.00', '}', '.', '#', '$', 'funds', '{', '$', '540.00', '}', '{', '$', '840.00', '}', '.', 'Store', '#', '$', 'XXXX/Unapplied', 'funds', 'XX/XX/XXXX/Total', '{', '$', '1600.00', '}', '.', 'All', 'totaling', '{', '$', '11000.00', '}', '.', 'The', 'following', 'information', 'readily', 'available', 'records', 'banks', ',', 'Wells', 'Fargo', 'Home', 'Mortgage', 'chose', 'apply', 'deposits', 'question', '.', 'There', 'several', 'unauthorized', 'escrow', 'analysis', 'without', 'knowledge', 'consent', ',', 'yet', 'I', 'received', 'definitive', 'answer', 'concerns', ',', 'robo', 'replies', '.', 'To', 'suggest', '``', 'We', 'unable', 'establish', 'contact', '``', ',', 'especially', 'I', 'make', 'opportunity', 'call', '(', ')', 'contact', 'Wells', 'Fargo', 'Ceo', "'s", 'directly', '.', 'It', 'hope', 'anyone', 'Wells', 'Fargo', 'Home', 'Mortgage', ',', 'address', 'repeated', 'concerns', '.']
